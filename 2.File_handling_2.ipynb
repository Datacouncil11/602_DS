# %%
f = open('Ratan_Tata', 'w' )

# %%
f.write('''Ratan Naval Tata (born 28 December 1937) is an Indian industrialist, philanthropist and former chairman of Tata Sons.
[2] He was a chairman of the Tata Group from 1990 to 2012,[2] and interim chairman from October 2016 through February 2017.
[2] He continues to head its charitable trusts.
[3][4] In 2008, he received the Padma Vibhushan, the second highest civilian honour in India, after receiving the Padma Bhushan, the third highest civilian honour in 2000.[5]''')
# Out:
# 464

# %%
f.close()

# %%
f = open('Ratan_Tata', 'r+')

# %%
f.read()
# Out:
# 'Ratan Naval Tata (born 28 December 1937) is an Indian industrialist, philanthropist and former chairman of Tata Sons.\n[2] He was a chairman of the Tata Group from 1990 to 2012,[2] and interim chairman from October 2016 through February 2017.\n[2] He continues to head its charitable trusts.\n[3][4] In 2008, he received the Padma Vibhushan, the second highest civilian honour in India, after receiving the Padma Bhushan, the third highest civilian honour in 2000.[5]'

# %%
f.seek(0)
# Out:
# 0

# %%
f.readline()
# Out:
# 'Ratan Naval Tata (born 28 December 1937) is an Indian industrialist, philanthropist and former chairman of Tata Sons.\n'

# %%
f.readline()
# Out:
# '[2] He was a chairman of the Tata Group from 1990 to 2012,[2] and interim chairman from October 2016 through February 2017.\n'

# %%
f.readline()
# Out:
# '[2] He continues to head its charitable trusts.\n'

# %%
f.readline()
# Out:
# '[3][4] In 2008, he received the Padma Vibhushan, the second highest civilian honour in India, after receiving the Padma Bhushan, the third highest civilian honour in 2000.[5]'

# %%
f.readline()
# Out:
# ''

# %%
f.seek(0)
# Out:
# 0

# %%
f.readlines()
# Out:
# ['Ratan Naval Tata (born 28 December 1937) is an Indian industrialist, philanthropist and former chairman of Tata Sons.\n',
#  '[2] He was a chairman of the Tata Group from 1990 to 2012,[2] and interim chairman from October 2016 through February 2017.\n',
#  '[2] He continues to head its charitable trusts.\n',
#  '[3][4] In 2008, he received the Padma Vibhushan, the second highest civilian honour in India, after receiving the Padma Bhushan, the third highest civilian honour in 2000.[5]']

# %%
f.seek(0)
# Out:
# 0

# %%
p = []
for i in f.readline():
    for j in i:
        
        p.append(j)

# %%
len(p)
# Out:
# 118

# %%
p
# Out:
# ['R',
#  'a',
#  't',
#  'a',
#  'n',
#  ' ',
#  'N',
#  'a',
#  'v',
#  'a',
#  'l',
#  ' ',
#  'T',
#  'a',
#  't',
#  'a',
#  ' ',
#  '(',
#  'b',
#  'o',
#  'r',
#  'n',
#  ' ',
#  '2',
#  '8',
#  ' ',
#  'D',
#  'e',
#  'c',
#  'e',
#  'm',
#  'b',
#  'e',
#  'r',
#  ' ',
#  '1',
#  '9',
#  '3',
#  '7',
#  ')',
#  ' ',
#  'i',
#  's',
#  ' ',
#  'a',
#  'n',
#  ' ',
#  'I',
#  'n',
#  'd',
#  'i',
#  'a',
#  'n',
#  ' ',
#  'i',
#  'n',
#  'd',
#  'u',
#  's',
#  't',
#  'r',
#  'i',
#  'a',
#  'l',
#  'i',
#  's',
#  't',
#  ',',
#  ' ',
#  'p',
#  'h',
#  'i',
#  'l',
#  'a',
#  'n',
#  't',
#  'h',
#  'r',
#  'o',
#  'p',
#  'i',
#  's',
#  't',
#  ' ',
#  'a',
#  'n',
#  'd',
#  ' ',
#  'f',
#  'o',
#  'r',
#  'm',
#  'e',
#  'r',
#  ' ',
#  'c',
#  'h',
#  'a',
#  'i',
#  'r',
#  'm',
#  'a',
#  'n',
#  ' ',
#  'o',
#  'f',
#  ' ',
#  'T',
#  'a',
#  't',
#  'a',
#  ' ',
#  'S',
#  'o',
#  'n',
#  's',
#  '.',
#  '\n']

# %%
p.count('Tata')
# Out:
# 0

# %%
f.seek(0)
# Out:
# 0

# %%
e = []
for i in f.read():
    e.append(i)

# %%
len(e)
# Out:
# 464

# %%
e
# Out:
# ['R',
#  'a',
#  't',
#  'a',
#  'n',
#  ' ',
#  'N',
#  'a',
#  'v',
#  'a',
#  'l',
#  ' ',
#  'T',
#  'a',
#  't',
#  'a',
#  ' ',
#  '(',
#  'b',
#  'o',
#  'r',
#  'n',
#  ' ',
#  '2',
#  '8',
#  ' ',
#  'D',
#  'e',
#  'c',
#  'e',
#  'm',
#  'b',
#  'e',
#  'r',
#  ' ',
#  '1',
#  '9',
#  '3',
#  '7',
#  ')',
#  ' ',
#  'i',
#  's',
#  ' ',
#  'a',
#  'n',
#  ' ',
#  'I',
#  'n',
#  'd',
#  'i',
#  'a',
#  'n',
#  ' ',
#  'i',
#  'n',
#  'd',
#  'u',
#  's',
#  't',
#  'r',
#  'i',
#  'a',
#  'l',
#  'i',
#  's',
#  't',
#  ',',
#  ' ',
#  'p',
#  'h',
#  'i',
#  'l',
#  'a',
#  'n',
#  't',
#  'h',
#  'r',
#  'o',
#  'p',
#  'i',
#  's',
#  't',
#  ' ',
#  'a',
#  'n',
#  'd',
#  ' ',
#  'f',
#  'o',
#  'r',
#  'm',
#  'e',
#  'r',
#  ' ',
#  'c',
#  'h',
#  'a',
#  'i',
#  'r',
#  'm',
#  'a',
#  'n',
#  ' ',
#  'o',
#  'f',
#  ' ',
#  'T',
#  'a',
#  't',
#  'a',
#  ' ',
#  'S',
#  'o',
#  'n',
#  's',
#  '.',
#  '\n',
#  '[',
#  '2',
#  ']',
#  ' ',
#  'H',
#  'e',
# ...

# %%
e.count('')
# Out:
# 0

# %%
p
# Out:
# ['R',
#  'a',
#  't',
#  'a',
#  'n',
#  ' ',
#  'N',
#  'a',
#  'v',
#  'a',
#  'l',
#  ' ',
#  'T',
#  'a',
#  't',
#  'a',
#  ' ',
#  '(',
#  'b',
#  'o',
#  'r',
#  'n',
#  ' ',
#  '2',
#  '8',
#  ' ',
#  'D',
#  'e',
#  'c',
#  'e',
#  'm',
#  'b',
#  'e',
#  'r',
#  ' ',
#  '1',
#  '9',
#  '3',
#  '7',
#  ')',
#  ' ',
#  'i',
#  's',
#  ' ',
#  'a',
#  'n',
#  ' ',
#  'I',
#  'n',
#  'd',
#  'i',
#  'a',
#  'n',
#  ' ',
#  'i',
#  'n',
#  'd',
#  'u',
#  's',
#  't',
#  'r',
#  'i',
#  'a',
#  'l',
#  'i',
#  's',
#  't',
#  ',',
#  ' ',
#  'p',
#  'h',
#  'i',
#  'l',
#  'a',
#  'n',
#  't',
#  'h',
#  'r',
#  'o',
#  'p',
#  'i',
#  's',
#  't',
#  ' ',
#  'a',
#  'n',
#  'd',
#  ' ',
#  'f',
#  'o',
#  'r',
#  'm',
#  'e',
#  'r',
#  ' ',
#  'c',
#  'h',
#  'a',
#  'i',
#  'r',
#  'm',
#  'a',
#  'n',
#  ' ',
#  'o',
#  'f',
#  ' ',
#  'T',
#  'a',
#  't',
#  'a',
#  ' ',
#  'S',
#  'o',
#  'n',
#  's',
#  '.',
#  '\n',
#  '[',
#  '2',
#  ']',
#  ' ',
#  'H',
#  'e',
# ...

# %%
f.seek(0)
# Out:
# 0

# %%
z = []
for i in f.readline():
    for j in i:
        for k in j:
            z.append(k)

# %%
z
# Out:
# ['R',
#  'a',
#  't',
#  'a',
#  'n',
#  ' ',
#  'N',
#  'a',
#  'v',
#  'a',
#  'l',
#  ' ',
#  'T',
#  'a',
#  't',
#  'a',
#  ' ',
#  '(',
#  'b',
#  'o',
#  'r',
#  'n',
#  ' ',
#  '2',
#  '8',
#  ' ',
#  'D',
#  'e',
#  'c',
#  'e',
#  'm',
#  'b',
#  'e',
#  'r',
#  ' ',
#  '1',
#  '9',
#  '3',
#  '7',
#  ')',
#  ' ',
#  'i',
#  's',
#  ' ',
#  'a',
#  'n',
#  ' ',
#  'I',
#  'n',
#  'd',
#  'i',
#  'a',
#  'n',
#  ' ',
#  'i',
#  'n',
#  'd',
#  'u',
#  's',
#  't',
#  'r',
#  'i',
#  'a',
#  'l',
#  'i',
#  's',
#  't',
#  ',',
#  ' ',
#  'p',
#  'h',
#  'i',
#  'l',
#  'a',
#  'n',
#  't',
#  'h',
#  'r',
#  'o',
#  'p',
#  'i',
#  's',
#  't',
#  ' ',
#  'a',
#  'n',
#  'd',
#  ' ',
#  'f',
#  'o',
#  'r',
#  'm',
#  'e',
#  'r',
#  ' ',
#  'c',
#  'h',
#  'a',
#  'i',
#  'r',
#  'm',
#  'a',
#  'n',
#  ' ',
#  'o',
#  'f',
#  ' ',
#  'T',
#  'a',
#  't',
#  'a',
#  ' ',
#  'S',
#  'o',
#  'n',
#  's',
#  '.',
#  '\n']

# %%
z.count('Tata')
# Out:
# 0

# %%
f.close()

# %%
f = open('Testing', 'w')

# %%
f.write('We are testing this line')
# Out:
# 24

# %%
f.close()

# %%
f = open('Testing', 'r+')

# %%
f.read()
# Out:
# 'We are testing this line'

# %%
f.seek(0)
# Out:
# 0

# %%
g = []
for i in f.readline():
    g.append(i)

# %%
g
# Out:
# ['W',
#  'e',
#  ' ',
#  'a',
#  'r',
#  'e',
#  ' ',
#  't',
#  'e',
#  's',
#  't',
#  'i',
#  'n',
#  'g',
#  ' ',
#  't',
#  'h',
#  'i',
#  's',
#  ' ',
#  'l',
#  'i',
#  'n',
#  'e']
